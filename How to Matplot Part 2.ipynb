# %% [markdown]
# # How To MatPlot Part 2

# %% [markdown]
# ## INDEX
#
# 1. [Labels & Titles](#MatPlot-Labels-and-Titles)
#     * [Set Font Properties](#Set-Font-Properties-for-Title-and-Labels)
#     * [Position the Title](#Position-the-Title)
#     * [Adding Grid Lines](#Adding-Grid-Lines)
#         * [Specify Which Grid Lines to Display](#Specify-Which-Grid-Lines-to-Display)
#         * [Set Line Properties for the Grid](#Set-Line-Properties-for-the-Grid)
#
#       <br>
# 1. [Subplot](#Subplot)

# %%
#import matplotlib

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # MatPlot Labels and Titles

# %% [markdown]
# With Pyplot, you can use the `xlabel()` and `ylabel() `functions to set a label for the x- and y-axis.

# %%
x1 = ['April', 'May', 'June', 'July']
y1 = [1, 5, 8, 10]

plt.plot(x1,y1, lw = 2.5, c = 'darkred')
plt.xlabel('Month')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# With Pyplot, you can use the `title()` function to set a title for the plot.

# %%
x1 = ['April', 'May', 'June', 'July']
y1 = [1, 5, 8, 10]

plt.plot(x1,y1, lw = 2.5, c = 'darkred')
plt.xlabel('Month')
plt.ylabel('Price')
plt.title ('Monthly Price')
plt.show()

# %% [markdown]
# ## Set Font Properties for Title and Labels

# %% [markdown]
# You can use the `fontdict` parameter in `xlabel()`, `ylabel()`, and` title()` to set font properties for the title and labels.

# %%
x1 = ['April', 'May', 'June', 'July']
y1 = [1, 5, 8, 10]

font1 = {'family':'Helvetica','color':'blue','size':20}
font2 = {'family':'Helvetica','color':'green','size':15}

plt.plot(x1,y1, lw = 2.5, c = 'darkred')
plt.xlabel('Month', fontdict = font2)
plt.ylabel('Price', fontdict = font2)
plt.title ('Monthly Price', fontdict = font1)
plt.show()

# %% [markdown]
# ### Available Types of Font
#
# 1. Sans-serif Fonts:
#
# * 'sans-serif' (default)
# * 'Arial'
# * 'Helvetica'
# * 'Calibri'
# * 'Verdana'
# * 'Geneva'
#
# 2. Serif Fonts:
#
# * 'serif'
# * 'Times New Roman'
# * 'Georgia'
# * 'Palatino'
# * 'Garamond'
#
# 3. Monospace Fonts:
#
# * 'monospace'
# * 'Courier New'
# * 'Consolas'
# * 'Lucida Console'

# %% [markdown]
# ## Position the Title
#
# You can use the `loc` parameter in `title()` to position the title.
#
# Legal values are: 'left', 'right', and 'center'. Default value is 'center'.

# %%
x1 = ['April', 'May', 'June', 'July']
y1 = [1, 5, 8, 10]

font1 = {'family':'Helvetica','color':'k','size':16}
font2 = {'family':'Helvetica','color':'green','size':15}

plt.plot(x1,y1, lw = 2.5, c = 'darkred')
plt.xlabel('Month', fontdict = font2)
plt.ylabel('Price', fontdict = font2)
plt.title ('Monthly Price', fontdict = font1, loc = 'left')
plt.show()

# %% [markdown]
# # Adding Grid Lines
#
# With Pyplot, you can use the` grid()` function to add grid lines to the plot.

# %%
x1 = ['April', 'May', 'June', 'July']
y1 = [1, 5, 8, 10]

plt.plot(x1,y1, marker = 'o' , lw = 2.5, c = 'aquamarine')
plt.grid()

# %% [markdown]
# ## Specify Which Grid Lines to Display
#
# You can use the `axis` parameter in the `grid()` function to specify which grid lines to display.
#
# Legal values are: 'x', 'y', and 'both'. Default value is 'both'.

# %%
#Show vertical grid

x1 = ['April', 'May', 'June', 'July']
y1 = [1, 5, 8, 10]

plt.plot(x1,y1, marker = 'o' , lw = 2.5, c = 'aquamarine')
plt.grid(axis = 'x')

# %%
#Show horizontal grid 
x1 = ['April', 'May', 'June', 'July']
y1 = [1, 5, 8, 10]

plt.plot(x1,y1, marker = 'o' , lw = 2.5, c = 'lightsalmon')
plt.grid(axis = 'y')

# %% [markdown]
# ## Set Line Properties for the Grid
#
# You can also set the line properties of the grid, like this:
# `grid(color = 'color', linestyle = 'linestyle', linewidth = number)`

# %%
x1 = ['April', 'May', 'June', 'July']
y1 = [1, 5, 8, 10]

gridstyle = {'c' : 'lightsalmon', 'ls' : 'dashed', 'lw' : 0.5} #add the style in brackets to store it in dictionary

plt.plot(x1,y1, marker = 'o' , lw = 2.5, c = 'aquamarine')
plt.grid(**gridstyle) #two asterisks open the dictionary

# %% [markdown]
# # Subplot
#
# With the `subplot()` function you can draw multiple plots in one figure:

# %%
#draw 2 plots

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# The subplot() function takes three arguments that describes the layout of the figure.
#
# **plt.subplot(1, 2, 1)**
# _#the figure has 1 row, 2 columns, and this plot is the first plot._
#
# **plt.subplot(1, 2, 2)**
# _#the figure has 1 row, 2 columns, and this plot is the fsecondplot._
#
# So, if we want a figure with 2 rows an 1 column (meaning that the two plots will be displayed on top of each other instead of side-by-side), we can write the syntax like this:

# %%
#draw 2 plots

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# You can draw as many plots you like on one figure, just descibe the number of rows, columns, and the index of the plot.

# %%
gridstyl = {'axis': 'y', 'ls': 'dashed', 'c':'khaki' }

#plot 1
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)
plt.title('first')
plt.grid(**gridstyl)
#plot 2

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3,  2)
plt.plot(x,y)
plt.title('second')
plt.grid(**gridstyl)
#plot 3

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)
plt.title('third')
plt.grid(**gridstyl)
#plot 4

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)
plt.title('fourth')
plt.grid(**gridstyl)
#plot 5

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)
plt.title('fifth')
plt.grid(**gridstyl)
#plot 6

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3,  6)
plt.plot(x,y)
plt.title('sixth')
plt.grid(**gridstyl)
#plt.subtitle() to add the title
plt.suptitle('Six Plots', fontsize=16)

plt.show()

# %% [markdown]
# ## [Back to TOP](#INDEX)
